# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# Year of exp vs Salary

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the dataset

# %%
df = pd.read_csv('Salary_Data.csv')
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
print(X, y)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]] [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
print(X_train, X_test, y_train, y_test)
# Out:
# [[ 9.6]
#  [ 4. ]
#  [ 5.3]
#  [ 7.9]
#  [ 2.9]
#  [ 5.1]
#  [ 3.2]
#  [ 4.5]
#  [ 8.2]
#  [ 6.8]
#  [ 1.3]
#  [10.5]
#  [ 3. ]
#  [ 2.2]
#  [ 5.9]
#  [ 6. ]
#  [ 3.7]
#  [ 3.2]
#  [ 9. ]
#  [ 2. ]
#  [ 1.1]
#  [ 7.1]
#  [ 4.9]
#  [ 4. ]] [[ 1.5]
#  [10.3]
#  [ 4.1]
#  [ 3.9]
#  [ 9.5]
#  [ 8.7]] [112635.  55794.  83088. 101302.  56642.  66029.  64445.  61111. 113812.
#   91738.  46205. 121872.  60150.  39891.  81363.  93940.  57189.  54445.
#  105582.  43525.  39343.  98273.  67938.  56957.] [ 37731. 122391.  57081.  63218. 116969. 109431.]

# %% [markdown]
# ## Training the Simple Linear Regression model on the Training set

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting the Test set results

# %%
y_pred = reg.predict(X_test)

# %% [markdown]
# ## Visualising the Training set results

# %%
plt.scatter(X_train, y_train, color='red')
plt.plot(X_train, reg.predict(X_train), color='blue')  # plot the regression line
plt.title('Salary vs Exp (Training Set)')
plt.xlabel('Years of Exp')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the Test set results

# %%
plt.scatter(X_test, y_test, color='red')
plt.plot(X_train, reg.predict(X_train))  # regression line is same anyway
plt.title('Salary vs Exp (Test Set)')
plt.xlabel('Years of Exp')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# #Making a single prediction (for example the salary of an employee with 12 years of experience)

# %%
print(reg.predict([[12]]))  # predict method needs 2d array as input
# Out:
# [138531.00067138]

# %% [markdown]
# # Getting the final linear regression equation with the values of the coefficients

# %%
print(reg.coef_, reg.intercept_)
# Out:
# [9312.57512673] 26780.09915062818

# %% [markdown]
# Salary = 9312.57512673*YearsofExp + 26780.09915062818
